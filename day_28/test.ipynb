# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# WARNING:tensorflow:From c:\ProgramData\miniconda3\envs\tf_env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 2s 2s/step - loss: 28.9810
# Epoch 2/500
# 1/1 [==============================] - 0s 38ms/step - loss: 23.1092
# Epoch 3/500
# 1/1 [==============================] - 0s 25ms/step - loss: 18.4833
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 14.8376
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 11.9633
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.6959
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.9063
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.4926
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3747
# Epoch 10/500
# ...

# %%
print(model.predict([10]))
# Out:
# 1/1 [==============================] - 0s 386ms/step
# [[18.979193]]

# %%
# Generate some random data
X_train = np.random.rand(100, 1)
y_train = 2 * X_train + 1 + np.random.randn(100, 1)

# Define the model with different dense units and input shape
model = keras.Sequential([keras.layers.Dense(units=10, input_shape=[1])])

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model for 5 epochs
model.fit(X_train, y_train, epochs=5)

# Predict values for 4 different inputs
print(model.predict([[0.1], [0.5], [0.8], [1.0]]))
# Out:
# Epoch 1/5
# 4/4 [==============================] - 0s 2ms/step - loss: 5.6399
# Epoch 2/5
# 4/4 [==============================] - 0s 3ms/step - loss: 5.6140
# Epoch 3/5
# 4/4 [==============================] - 0s 2ms/step - loss: 5.5886
# Epoch 4/5
# 4/4 [==============================] - 0s 3ms/step - loss: 5.5627
# Epoch 5/5
# ...
# 1/1 [==============================] - 0s 208ms/step
# [[-0.01111246  0.01692768  0.0744243   0.04961923  0.07591294  0.04350364
#    0.0254226  -0.00249303  0.08125526  0.07220412]
#  [-0.13516632  0.00506222  0.2926492   0.16856933  0.30009627  0.13798042
#    0.04754762 -0.09206176  0.3268223   0.28154266]
#  [-0.22820671 -0.00383688  0.4563179   0.2577819   0.46823376  0.208838
#    0.06414139 -0.15923831  0.51099765  0.43854657]
#  [-0.29023364 -0.00976961  0.56543034  0.31725693  0.5803254   0.2560764
#    0.0752039  -0.20402268  0.63378114  0.5432159 ]]
