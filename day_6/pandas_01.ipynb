# %% [markdown]
# # How to import dataset in paython using pandas library\
# Written by: M.Danish Azeem\
# Date: 07.11.2023\
# Email: danishazeem365@gmail.com

# %%
# step-1
# importing libraries
import pandas as pd

# %%
#step-2
#reading/importing dataset
df = pd.read_excel("pandas_01_day6.xlsx") 
# Assighnment
# write the path if you want to load data from day_1 to day_6

# %%
# Assighnment
d2 = pd.read_excel("../day_1/Book1.xlsx")
d2.head()
# Out:
#   Unnamed: 0      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN  STUDENTES NAME        NaN        NaN          C        NaN
# 1        SR.            NAME  SUBJECT 1  SUBJECT 2  SUBJECT 3  SUBJECT 4
# 2          1               A         45         76         66         65
# 3          2               B         46         78         77         45
# 4          3               C         55         82         88         43
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1      TOTAL       MAX         MIN      COUNT        AVE        %TAGE
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13
# 0         NaN         NaN
# 1      RESULT       GRADE
# ...

# %%
df
# Out:
#    height  weight favourite _dish
# 0     5.8     101   Chicken Pulao
# 1     6.2      92         Biryani
# 2     5.9      62   Karahi Ghosht
# 3     5.9      95   Chicken Pulao
# 4     5.9      55   Chicken Pulao
# ..    ...     ...             ...
# 82    5.4      55           Pasta
# 83    5.9      75   Karahi Ghosht
# 84    5.4      61         Biryani
# 85    6.2      68   Chicken Pulao
# 86    5.1      96         Biryani
#
# [87 rows x 3 columns]

# %%
df.head(10)
# Out:
#   height  weight favourite _dish
# 0    5.8     101   Chicken Pulao
# 1    6.2      92         Biryani
# 2    5.9      62   Karahi Ghosht
# 3    5.9      95   Chicken Pulao
# 4    5.9      55   Chicken Pulao
# 5    5.3      59         Biryani
# 6    5.6      50           Pasta
# 7    5.9      76         Biryani
# 8    5.1      78         Biryani
# 9    5.4      68         Biryani

# %%
df.tail(6)
# Out:
#    height  weight favourite _dish
# 81    5.5      52   Karahi Ghosht
# 82    5.4      55           Pasta
# 83    5.9      75   Karahi Ghosht
# 84    5.4      61         Biryani
# 85    6.2      68   Chicken Pulao
# 86    5.1      96         Biryani

# %%
df.shape
# Out:
# (87, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   height           87 non-null     object
#  1   weight           87 non-null     int64
#  2   favourite _dish  87 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB

# %%
import json

def read_data_from_json_file(file_path):
    with open(03_strings.py, 'r') as file:
        data = json.load(file)
    return data
# Out:
#   Cell In[34], line 4
#     with open(03_strings.py, 'r') as file:
#                 ^
# SyntaxError: invalid decimal literal
