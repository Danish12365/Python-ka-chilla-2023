# %% [markdown]
# # Linear Regression in Python
#
#
# Written by: M.Danish Azeem\
# Date: 01.13.2024\
# Email: danishazeem365@gmail.com

# %%
# import librases
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# other
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
x = df[['sepal_length', 'sepal_width','petal_length']]
y = df['petal_width']

# %%
multilinear_regression = df[["sepal_length", "sepal_width","petal_length","petal_width"]]
multilinear_regression
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
multilinear_regression.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# dtype: int64

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %%
y
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, Length: 150, dtype: float64

# %%
sns.lmplot(data=multilinear_regression, x='sepal_length', y='petal_width')

# %%
sns.lmplot(data=multilinear_regression, x='sepal_width', y='petal_width')

# %%
sns.lmplot(data=multilinear_regression, x='petal_length', y='petal_width')

# %%
sns.boxplot(data=multilinear_regression, y='petal_width')
# Out:
# <Axes: ylabel='petal_width'>

# %%
x = multilinear_regression[['sepal_length', 'sepal_width','petal_length']]
y = multilinear_regression['petal_width']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# model bula len
model = LinearRegression()

# train the model
model.fit(x,y)

#prediction
model.predict([[1.5,2.5,3.5]])
# Out:
# c:\Users\Danish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.84015576])

# %%
#model evalution with metrics
# r2
# mean squared error
# MAE
# RMSE

x_train, x_test, y_train, y_test = train_test_split(x,y, train_size= 0.8)

# model
model = LinearRegression()

# train
model.fit(x_train, y_train)

# prediction
predictions = model.predict(x_test)

# %%
sns.scatterplot(x= y_test, y= predictions)
# Out:
# <Axes: xlabel='petal_width'>

# %%
model.score(x_test, y_test)
# Out:
# 0.8975860886960086

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

MAE = mean_absolute_error(y_true=y_test, y_pred=predictions)
MSE = mean_squared_error(y_true=y_test, y_pred=predictions)
RMSE = mean_squared_error(y_true=y_test, y_pred=predictions, squared= False)
R2 = r2_score(y_true=y_test, y_pred=predictions)

print("MAE: ", MAE)
print("MSE: ",MSE)
print("RMSE: ",RMSE)
print("R_squared: ",R2)
# Out:
# MAE:  0.16636417029533254
# MSE:  0.05312437165807597
# RMSE:  0.23048724836327925
# R_squared:  0.8975860886960086

# %% [markdown]
# **Here's an assessment of the model's performance based on the provided metrics:**
#
# **1. MAE (Mean Absolute Error):**
#    - Value: 0.16636417029533254
#    - Interpretation: On average, the model's predictions are off by about 0.166 units from the actual values. This is relatively low, suggesting good accuracy.
#
# **2. MSE (Mean Squared Error):**
#    - Value: 0.05312437165807597
#    - Interpretation: This measures the average squared difference between predictions and actual values. It's lower than the MAE, indicating a good fit.
#
# **3. RMSE (Root Mean Squared Error):**
#    - Value: 0.23048724836327925
#    - Interpretation: This is in the same units as the target variable and gives an idea of the average magnitude of the errors. It's relatively low in this case.
#
# **4. R_squared (R-squared):**
#    - Value: 0.8975860886960086
#    - Interpretation: This is quite high, indicating that the model explains 89.76% of the variance in the target variable. This is a strong result.
#
# **Overall Assessment:**
#
# - Based on these metrics, the model is performing well. It has a low MAE, low MSE, low RMSE, and a high R-squared value. These scores suggest that it's accurately capturing the patterns in the data and making reliable predictions.
#
# **Contextual Considerations:**
#
# - **Domain-Specific Thresholds:** While these scores are generally considered good, the specific thresholds for "good" performance can vary depending on the domain and problem you're addressing. Consult with experts in your field to determine appropriate benchmarks.
# - **Error Tolerance:** Consider the level of error that's acceptable for your application. A lower MAE might be crucial in certain scenarios, while a higher R-squared might be more important in others.
# - **Data Variability:** The scale of the target variable can also influence metric interpretation. A MAE of 0.166 might be significant for a variable with a narrow range, but less so for a variable with a wider range.
#
# **Conclusion:**
#
# Overall, based on the provided metrics and assuming a context where these scores are considered satisfactory, this model is demonstrating strong predictive performance.
