# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Written by: M.Danish Azeem\
# Date: 09.12.2023\
# Email: danishazeem365@gmail.com

# %% [markdown]
# # Exporatory Data Analysis:
# Exporatorey Data Analysis (EDA) is a method used to `analyze` and `summarize` datasets. In python you can use the Pandas library to perform EDA on a dataset.

# %%
import pandas as pandas
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# sumarize (sumary statistics)
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()* 100/ len(df)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# visulize the nan value in heatmap
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
df.drop(columns="deck", inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 14)

# %%
sns.countplot(data=df, x="survived")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# it is made by  x=catagorical and y=numaric valuies 
sns.barplot(data=df, x="survived", y="fare", hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
# we give it categeores he himself count and made the plot
sns.countplot(x="pclass", data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
# hist is made by numaric valuies. its data point and unique valuios are big 
sns.histplot(data=df, x="age", bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age'].hist(bins=30, color='darkred', alpha=0.75)
# Out:
# <Axes: >

# %%
# one side categoric and other side numaric values in boxplot
sns.boxplot(data=df, y='age', x='survived', hue='who')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
# scatterplot
sns.scatterplot(x='age', y='fare', data=df, hue='pclass')
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
sns.pairplot(df, hue='survived')

# %%
df.groupby(['pclass', 'who'])['survived'].mean().unstack().plot(kind='bar', stacked=True)
plt.xticks([0,1,2], ['A','B','C'], rotation=0)
# Out:
# ([<matplotlib.axis.XTick at 0x179a16ca390>,
# ...
#  [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C')])

# %%
# swarmplot
sns.swarmplot(data=df, x='survived', y='age', hue='who')
# Out:
# <Axes: xlabel='survived', ylabel='age'>
# c:\Users\Danish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# pointplot
sns.catplot(x='pclass', y='fare', hue='embarked', kind='point', data=df)

# %%
sns.lmplot(data=df[df['fare'] < 300], x='age', y='fare', hue='pclass')  # assighnment

# %%
# sns.lmplot(data=df, x='fare', y='age')
# sns.lmplot(data=df, x='age', y=df['fare'] <300)
# sns.lmplot(data=df[df['fare'] < 300], x='age', y='fare )  # assighnment 

# Add a new column based on a condition (fare < 300)
# df['condition'] = df['fare'] < 300

# Create a new column 'condition' based on the fare
df['condition'] = df['fare'].apply(lambda x: 'low' if x < 300 else 'high')

# Use lmplot with hue for conditional plotting
sns.lmplot(data=df, x='age', y='fare', hue='condition', markers=["o", "s"], palette={"low": "blue", "high": "red"})

# %%
import pandas as pd
df['age_group'] = pd.cut(df['age'], [0,10,18,30,50,80],
                         labels=['Baby', 'Child', 'Young_adult', 'Adult', 'Senior'])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone condition    age_group
# 0    man        True  Southampton    no  False       low  Young_adult
# 1  woman       False    Cherbourg   yes  False       low        Adult
# 2  woman       False  Southampton   yes   True       low  Young_adult
# 3  woman       False  Southampton   yes  False       low        Adult
# 4    man        True  Southampton    no   True       low        Adult

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'condition', 'age_group'],
#       dtype='object')

# %%
df.groupby("age_group")["fare"].mean().plot(kind="bar")
# Out:
# C:\Users\Danish\AppData\Local\Temp\ipykernel_9752\1691103867.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("age_group")["fare"].mean().plot(kind="bar")
# <Axes: xlabel='age_group'>

# %%
sns.pairplot(df, hue='survived', vars=['age','fare', 'pclass'])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone condition    age_group
# 0    man        True  Southampton    no  False       low  Young_adult
# 1  woman       False    Cherbourg   yes  False       low        Adult
# 2  woman       False  Southampton   yes   True       low  Young_adult
# 3  woman       False  Southampton   yes  False       low        Adult
# 4    man        True  Southampton    no   True       low        Adult

# %%
# familey_size
# df['familey_size'] = pd.cut([])

# Define a function to determine family size
def get_family_size(row):
    if row['sibsp'] == 0 and row['parch'] == 0:
        return 'Single'
    elif row['sibsp'] == 1 and row['parch'] == 0:
        return 'Couple (No Children)'
    elif row['sibsp'] > 1 and row['parch'] == 0:
        return 'Family (No Children)'
    elif row['sibsp'] == 0 and row['parch'] == 1:
        return 'Single Parent'
    elif row['sibsp'] == 1 and row['parch'] == 1:
        return 'Nuclear Family'
    elif row['sibsp'] > 1 and row['parch'] == 1:
        return 'Extended Family'

# Create 'family_size' column based on conditions
df['family_size'] = df.apply(get_family_size, axis=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'condition', 'age_group', 'family_size'],
#       dtype='object')

# %%
df.groupby("family_size")["fare"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='family_size'>
